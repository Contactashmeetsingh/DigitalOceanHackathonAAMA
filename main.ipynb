# %%
import os
import sys
import requests

API_TOKEN = os.getenv("DO_TOKEN") or input("DigitalOcean API token: ")

headers = {"Authorization": f"Bearer {API_TOKEN}"}
response = requests.get("https://api.digitalocean.com/v2/account", headers=headers)

if response.status_code == 200:
    print("✅ API key is valid.")
else:
    print(f"❌ API key test failed – HTTP {response.status_code}")
    sys.exit(1)
# Out:
# ❌ API key test failed – HTTP 401
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1
# /Users/amannindra/Projects/DigitalOcean/venv/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3756: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
